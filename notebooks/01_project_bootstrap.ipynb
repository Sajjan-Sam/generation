# %%
from pathlib import Path
import os, sys, json, platform
from datetime import datetime

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
env = {"timestamp": datetime.now().isoformat(), "python": sys.version, "platform": platform.platform()}
try:
    import torch
    env["torch_version"] = torch.__version__
    env["cuda_available"] = torch.cuda.is_available()
    env["cuda_device_count"] = torch.cuda.device_count()
    env["gpu_names"] = [torch.cuda.get_device_name(i) for i in range(torch.cuda.device_count())] if torch.cuda.is_available() else []
except Exception as e:
    env["torch_error"] = str(e)
(ROOT / "reports" / "notes" / "environment_report.json").write_text(json.dumps(env, indent=2), encoding="utf-8")
print(json.dumps(env, indent=2))
# Out:
# {
#   "timestamp": "2026-04-06T11:05:38.320122",
#   "python": "3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:40:32) [GCC 12.3.0]",
#   "platform": "Linux-6.8.0-59-generic-x86_64-with-glibc2.35",
#   "torch_version": "2.6.0+cu124",
#   "cuda_available": true,
#   "cuda_device_count": 1,
#   "gpu_names": [
#     "NVIDIA H100 NVL"
#   ]
# }
